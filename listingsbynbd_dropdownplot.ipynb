# %%
import plotly.graph_objects as go
import plotly.express as px
import plotly

import pandas as pd

# %%
listings = pd.read_csv("../data/airbnb/listings_subset.csv")

# %%
listings = listings.sort_values(['host_id', 'firstreview_year'])

# %%
listings.head()
# Out:
#             id                     neighbourhood state  host_id  host_since  \
# 7         4501                              Shaw    DC     1585  2008-08-08
# 1         3362                              Shaw    DC     2798  2008-09-07
# 29       25366                              Shaw    DC     2798  2008-09-07
# 2694  14005162  Near Northeast/H Street Corridor    DC     2798  2008-09-07
# 3844  16587642                         Gallaudet    DC     2798  2008-09-07
#
#      first_review host_neighbourhood property_type        room_type  \
# 7      2009-01-21               Shaw         House     Private room
# 1      2009-01-21               Shaw     Townhouse  Entire home/apt
# 29     2010-09-06               Shaw     Townhouse  Entire home/apt
# 2694   2016-09-14               Shaw     Apartment  Entire home/apt
# 3844   2017-03-16               Shaw     Townhouse  Entire home/apt
#
#       host_listings_count monthly_price firstreview_year hostsince_year
# 7                     1.0           NaN             2009           2008
# 1                     5.0           NaN             2009           2008
# 29                    5.0           NaN             2010           2008
# 2694                  5.0           NaN             2016           2008
# 3844                  5.0           NaN             2017           2008

# %%
#subset listing data  

ll = listings[['id', 'host_id', 'state','neighbourhood', 'firstreview_year','hostsince_year', 'host_listings_count']].copy()

# %%
ll.head()
# Out:
#             id  host_id state                     neighbourhood  \
# 7         4501     1585    DC                              Shaw
# 1         3362     2798    DC                              Shaw
# 29       25366     2798    DC                              Shaw
# 2694  14005162     2798    DC  Near Northeast/H Street Corridor
# 3844  16587642     2798    DC                         Gallaudet
#
#      firstreview_year hostsince_year  host_listings_count
# 7                2009           2008                  1.0
# 1                2009           2008                  5.0
# 29               2010           2008                  5.0
# 2694             2016           2008                  5.0
# 3844             2017           2008                  5.0

# %% [markdown]
# - To get the number of unique hosts by year, I am using the first review year as a proxy for when the listing was established

# %%
#groupby listings by nbd and review_year
ll = ll.groupby(['neighbourhood', 'firstreview_year', 'state']).firstreview_year.agg('count').to_frame('listcount').reset_index()


#get cumulative sum
ll['listings_cumulative'] = ll.groupby(['neighbourhood'])['listcount'].apply(lambda x: x.cumsum())

# %%
#to get host data we must drop duplicates a host can have multiple listings

hostdata = listings.drop_duplicates("host_id", keep = 'first')

# %%
hh = hostdata.groupby(['neighbourhood', 'firstreview_year']).firstreview_year.agg('count').to_frame('hostcount').reset_index()

hh['hosts_cumulative'] = hh.groupby(['neighbourhood'])['hostcount'].apply(lambda x: x.cumsum())

# %% [markdown]
# To create the dropdown plot, I need a list of dataframes organized by neighbourhood and year

# %%
labels = []

labels = hh.neighbourhood.unique().tolist()
labels.append('All Neighbourhoods')

# %%
data_list = []

for l in labels:
    k = ll[ll['neighbourhood']==l]
    if not k.empty:
        data_list.append(k)

# %%
data_host = []

for l in labels:
    k = hh[hh['neighbourhood']==l]
    if not k.empty:
        data_host.append(k)

# %%
- buttonbox down or title up
- hovertext to left,

# %%
hostdata.shape
# Out:
# (6021, 13)

# %%
hostdata = hostdata.groupby(['firstreview_year']).firstreview_year.agg('count').to_frame('host_count').reset_index()
hostdata['host_total'] = hostdata.host_count.cumsum()

# %%
listdata = listings.groupby(['firstreview_year']).firstreview_year.agg('count').to_frame('list_count').reset_index()
hostdata['list_total'] = listdata.list_count.cumsum()

# %%
df = hostdata.copy()

# %%
df.tail()
# Out:
#    firstreview_year  host_count  host_total  list_total
# 7              2016         921        1927        2598
# 8              2017        1253        3180        4365
# 9              2018        1069        4249        6126
# 10             2019         627        4876        7274
# 11              NaT        1145        6021        9081

# %%
fig = go.Figure()


for i, d in enumerate(data_list):
    
    fig.add_trace(go.Scatter( x=d["firstreview_year"], 
                                y=d["listings_cumulative"], 
                                mode = "lines+markers",
                                marker_color="#601A4A",
                                text=d['neighbourhood'],
                                showlegend= True, 
                                legendgroup = labels[i],
                            name = "listings",
                           hovertemplate = "type:LISTING %{y} Unique Listings")
                  
                                )
    

fig.add_trace(go.Scatter( x=df["firstreview_year"], 
                                y=df["list_total"], 
                                mode = "lines+markers",
                                marker_color="#601A4A",
                                text= 'All Neighbourhoods',
                                showlegend= True, 
                                legendgroup = 'All Neighbourhoods',
                            name = "listings",
                        hovertemplate = "type:LISTING %{y} Unique Listings")
                  
                                )    

for i, d in enumerate(data_host):
    
    fig.add_trace(go.Scatter( x=d["firstreview_year"], 
                                y=d["hosts_cumulative"], 
                                mode = "lines+markers",
                                #line=dict(color=hh['neighbourhood']),
                                marker_color="#EE442F",
                                 text=d['neighbourhood'], 
                            legendgroup = labels[i],
                            name = "host", 
                            hovertemplate = "type:HOST %{y} unique hosts"
                              )
                                
                                )
    


fig.add_trace(go.Scatter( x=df["firstreview_year"], 
                                y=df["host_total"], 
                                mode = "lines+markers",
                                marker_color="#EE442F",
                                text= 'All Neighbourhoods',
                                showlegend= True, 
                                legendgroup = 'All Neighbourhoods',
                            name = "hosts", 
                        hovertemplate = "type:HOST %{y} unique hosts")
                  
                                )  

    
### Create buttons for drop down menu
buttons = []
for i, label in enumerate(labels):
    visibility = [i==j for j in range(len(labels))]
    button = dict(
                 label =  label,
                 method = 'restyle',
                 args = [{'visible': visibility},
                     {'title': label}])
    buttons.append(button)

updatemenus = list([
    dict(x = 1,
        y = 1.15,
        #xref = 'paper',
        #yref = 'paper',
        yanchor = 'top',
        active = 1,
        showactive = False,
        buttons = buttons
    )
])



fig['layout']['xaxis']['title'] = ''


#fig['layout']['xaxis']['type'] = 'date'
fig['layout']['xaxis']['gridcolor'] = '#d3d3d3'
fig['layout']['yaxis']['title'] = 'Count'
fig['layout']['xaxis']['title'] = 'Year'
fig['layout']['yaxis']['type'] = 'linear'
#fig['layout']['yaxis']['range'] = [0,1200]
fig['layout']['yaxis']['gridcolor'] = '#d3d3d3'
fig['layout']["plot_bgcolor"]= "#FDFEFE" 
fig['layout']["width"]= 900
fig['layout']["height"] = 500
fig['layout']['showlegend'] = False

fig['layout']['updatemenus'] = updatemenus
fig['layout']['title'] = '<b>Airbnb Listings & Hosts by DC Neighbourhood</b>'
fig['layout']['title']['x'] = 0.099
fig['layout']['title']['y'] = 0.9
fig['layout']['title']['xref'] = 'container'
fig['layout']['title']['yref'] = 'container'



plotly.offline.plot(fig, "listings.html")
fig.show()
# Out:
# <div>
#
#
#             <div id="94fff4d7-94ff-419e-9777-71208dccaa4c" class="plotly-graph-div" style="height:500px; width:900px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("94fff4d7-94ff-419e-9777-71208dccaa4c")) {
#                     Plotly.newPlot(
#                         '94fff4d7-94ff-419e-9777-71208dccaa4c',
#                         [{"hovertemplate": "type:LISTING %{y} Unique Listings", "legendgroup": "16th Street Heights", "marker": {"color": "#601A4A"}, "mode": "lines+markers", "name": "listings", "showlegend": true, "text": ["16th Street Heights", "16th Street Heights", "16th Street Heights", "16th Street Heights", "16th Street Heights", "16th Street Heights", "16th Street Heights", "16th Street Heights", "16th Street Heights"], "type": "scatter", "x": ["2009", "2013", "2014", "2015", "2016", "2017", "2018", "2019", "NaT"], "y": [1, 4, 12, 25, 49, 82, 121, 146, 175]}, {"hovertemplate": "type:LISTING %{y} Unique Listings", "legendgroup": "Adams Morgan", "marker": {"color": "#601A4A"}, "mode": "lines+markers", "name": "listings", "showlegend": true, "text": ["Adams Morgan", "Adams Morgan", "Adams Morgan", "Adams Morgan", "Adams Morgan", "Adams Morgan", "Adams Morgan", "Adams Morgan", "Adams Morgan", "Adams Morgan", "Adams Morgan"], "type": "scatter", "x": ["2009", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019", "NaT"], "y": [2, 3, 4, 7, 18, 61, 118, 164, 209, 231, 288]}, {"hovertemplate": "type:LISTING %{y} Unique Listings", "legendgroup": "American University Park", "marker": {"color": "#601A4A"}, "mode": "lines+markers", "name": "listings", "showlegend": true, "text": ["American University Park", "American University Park", "American University Park", "American University Park", "American University Park", "American University Park", "American University Park", "American University Park"], "type": "scatter", "x": ["2013", "2014", "2015", "2016", "2017", "2018", "2019", "NaT"], "y": [1, 2, 7, 12, 26, 30, 39, 47]}, {"hovertemplate": "type:LISTING %{y} Unique Listings", "legendgroup": "Anacostia", "marker": {"color": "#601A4A"}, "mode": "lines+markers", "name": "listings", "showlegend": true, "text": ["Anacostia", "Anacostia", "Anacostia", "Anacostia", "Anacostia", "Anacostia", "Anacostia", "Anacostia", "Anacostia"], "type": "scatter", "x": ["2010", "2012", "2014", "2015", "2016", "2017", "2018", "2019", "NaT"], "y": [1, 2, 3, 6, 13, 29, 38, 48, 55]}, {"hovertemplate": "type:LISTING %{y} Unique Listings", "legendgroup": "Arboretum", "marker": {"color": "#601A4A"}, "mode": "lines+markers", "name": "listings", "showlegend": true, "text": ["Arboretum", "Arboretum"], "type": "scatter", "x": ["2016", "2017"], "y": [1, 3]}, {"hovertemplate": "type:LISTING %{y} Unique Listings", "legendgroup": "Barney Circle", "marker": {"color": "#601A4A"}, "mode": "lines+markers", "name": "listings", "showlegend": true, "text": ["Barney Circle", "Barney Circle", "Barney Circle", "Barney Circle", "Barney Circle", "Barney Circle", "Barney Circle", "Barney Circle", "Barney Circle"], "type": "scatter", "x": ["2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019", "NaT"], "y": [3, 4, 9, 20, 43, 70, 101, 108, 125]}, {"hovertemplate": "type:LISTING %{y} Unique Listings", "legendgroup": "Barry Farm", "marker": {"color": "#601A4A"}, "mode": "lines+markers", "name": "listings", "showlegend": true, "text": ["Barry Farm", "Barry Farm", "Barry Farm", "Barry Farm"], "type": "scatter", "x": ["2016", "2018", "2019", "NaT"], "y": [1, 5, 10, 12]}, {"hovertemplate": "type:LISTING %{y} Unique Listings", "legendgroup": "Bellevue", "marker": {"color": "#601A4A"}, "mode": "lines+markers", "name": "listings", "showlegend": true, "text": ["Bellevue", "Bellevue", "Bellevue", "Bellevue"], "type": "scatter", "x": ["2017", "2018", "2019", "NaT"], "y": [3, 11, 15, 20]}, {"hovertemplate": "type:LISTING %{y} Unique Listings", "legendgroup": "Benning", "marker": {"color": "#601A4A"}, "mode": "lines+markers", "name": "listings", "showlegend": true, "text": ["Benning", "Benning", "Benning", "Benning", "Benning", "Benning"], "type": "scatter", "x": ["2015", "2016", "2017", "2018", "2019", "NaT"], "y": [1, 3, 7, 10, 16, 21]}, {"hovertemplate": "type:LISTING %{y} Unique Listings", "legendgroup": "Benning Heights", "marker": {"color": "#601A4A"}, "mode": "lin ...

# %%
df = df.drop([11], axis=0)

# %%
df
# Out:
#    firstreview_year  host_count  host_total  list_total
# 0              2009           9           9          10
# 1              2010          13          22          28
# 2              2011          21          43          56
# 3              2012          50          93         120
# 4              2013         104         197         258
# 5              2014         267         464         614
# 6              2015         542        1006        1348
# 7              2016         921        1927        2598
# 8              2017        1253        3180        4365
# 9              2018        1069        4249        6126
# 10             2019         627        4876        7274

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x=df['firstreview_year'], 
                                y=df['host_total'], 
                               marker_color="#EE442F", 
                                showlegend = True,
                            name = "Hosts", 
                            hovertemplate = "%{y} unique hosts in year %{x}"))


fig.add_trace(go.Scatter(x=df['firstreview_year'], 
                                y=df['list_total'], 
                               marker_color="#601A4A",
                                 
                                showlegend = True,
                            name = "Listings", 
                            hovertemplate = "%{y} unique listings in year %{x}"))


fig['layout']['xaxis']['title'] = ''


#fig['layout']['xaxis']['type'] = 'date'
fig['layout']['xaxis']['gridcolor'] = '#d3d3d3'
fig['layout']['yaxis']['title'] = 'Count'
fig['layout']['xaxis']['title'] = 'Year'
fig['layout']['yaxis']['type'] = 'linear'
#fig['layout']['yaxis']['range'] = [0,1200]
fig['layout']['yaxis']['gridcolor'] = '#d3d3d3'
fig['layout']["plot_bgcolor"]= "#FDFEFE" 
fig['layout']["width"]= 900
fig['layout']["height"] = 500
fig['layout']['showlegend'] = False

#fig['layout']['updatemenus'] = updatemenus
fig['layout']['title'] = '<b>Airbnb Listings & Hosts in DC</b>'
fig['layout']['title']['x'] = 0.099
fig['layout']['title']['y'] = 0.9
fig['layout']['title']['xref'] = 'container'
fig['layout']['title']['yref'] = 'container'



plotly.offline.plot(fig, "totals.html")
fig.show()
# Out:
# <div>
#
#
#             <div id="e89e2d68-e38d-40c1-80b3-1d565fd83c2d" class="plotly-graph-div" style="height:500px; width:900px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e89e2d68-e38d-40c1-80b3-1d565fd83c2d")) {
#                     Plotly.newPlot(
#                         'e89e2d68-e38d-40c1-80b3-1d565fd83c2d',
#                         [{"hovertemplate": "%{y} unique hosts in year %{x}", "marker": {"color": "#EE442F"}, "name": "Hosts", "showlegend": true, "type": "scatter", "x": ["2009", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019"], "y": [9, 22, 43, 93, 197, 464, 1006, 1927, 3180, 4249, 4876]}, {"hovertemplate": "%{y} unique listings in year %{x}", "marker": {"color": "#601A4A"}, "name": "Listings", "showlegend": true, "type": "scatter", "x": ["2009", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019"], "y": [10, 28, 56, 120, 258, 614, 1348, 2598, 4365, 6126, 7274]}],
#                         {"height": 500, "plot_bgcolor": "#FDFEFE", "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "s ...

# %%
import numpy as np

years = np.arange(2009, 2020, 1)

# %%
years = list(years)

# %%
year_list = []

for l in years:
    year_list.append(ll[ll['firstreview_year']==l])

# %%
ll.head()
# Out:
#          neighbourhood  firstreview_year state  listcount  listings_cumulative
# 0  16th Street Heights              2009    DC          1                    1
# 1  16th Street Heights              2013    DC          3                    4
# 2  16th Street Heights              2014    DC          8                   12
# 3  16th Street Heights              2015    DC         13                   25
# 4  16th Street Heights              2016    DC         24                   49
